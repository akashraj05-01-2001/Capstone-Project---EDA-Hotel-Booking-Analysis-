# %% [markdown]
# <a href="https://colab.research.google.com/github/akashraj05-01-2001/Capstone-Project---EDA-Hotel-Booking-Analysis-/blob/main/Copy_of_Sample_EDA_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA (Hotel Booking Analysis)
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Akash Raj

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This is an Exploratory Data Analysis for a hotel booking dataset which  contains booking information for a city hotel and a resort hotel. This whole project aims at providing valuable insights from the data set (Hotel booking dataset) which further might prove valuable for the business.
#
# This dataset contains 119390 rows and 32 columns like 'hotel'(H1- Resort Hotel and H2- City Hotel), 'arrival_date_year', 'arrival_date_month', 'arrival_date_day_of_month' which represents Year, Month and Date of arrival date of guests respectively. Further, there are more columns like- 'stays_in_weekend_nights' and 'stays_in_week_nights' which represents the number of weekend and week nights respectively in which the guests stayed or booked to stay at the hotel. Columns like 'adults', 'children', 'babies' represents number of adults, children and babies respectively and column 'meal' represents the kind of meal customer opted for,  etc.
#
# In order to provide valuable insights, first i have gone through the dataset throughly and understood the data, data types, null, missing and duplicate values, and did the needful in order to clean the dataset so that maximum accuracy can be achieved during data visualization. Then i have approached towards data visualization plotting different types of plot like bar plot, pie chart, histogram, scatter plot, line plot, etc. Each of these plots is sufficient in providing insight which could lead to a positive impact on the business. At last, i have also concluded the conclusions made from each plot.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/akashraj05-01-2001/Capstone-Project---EDA-Hotel-Booking-Analysis-

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **In the modern hospitality industry, efficient hotel management relies heavily on data-driven decisions to enhance customer experiences, optimize operations, and maximize revenue. To address this need, my project aims to conduct a comprehensive analysis of hotel booking data to provide actionable insights and solutions for our client XYZ Hotels.**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To address the above problem statement my project aims to provide insights to achieve the following objectives:
#
# 1.   Cancellation Pattern recognition
# 2.   Customer Experience enhancement
# 3.   Operational efficiency
# 4.   Customer segment analysis
# 5.   Revenue maximization

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

from google.colab import drive
drive.mount("/content/drive")   #Mounting the drive by giving access to google drive which contains the data set
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# storing the filepath in filepath variable:
filepath = "/content/drive/MyDrive/Colab Notebooks/Capstone Projects/Capstone Project: Exploratory Data Analysis/Hotel Bookings.csv"

#Storing the dataset in hotel_df variable:

hotel_df = pd.read_csv(filepath)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look

hotel_df.head(5) # Displaying the first 5 rows
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel_df.tail() # # Displaying the last 5 rows
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119385             August                        35
# 119386             August                        35
# 119387             August                        35
# 119388             August                        35
# 119389             August                        35
#
#         arrival_date_day_of_month  stays_in_weekend_nights  \
# 119385                         30                        2
# 119386                         31                        2
# 119387                         31                        2
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

hotel_df.shape
# Out:
# (119390, 32)

# %% [markdown]
# The data set contain 119390 rows and 32 columns

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info

hotel_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count

duplicate_count = hotel_df.duplicated().sum()

print(f"Number of duplicate rows in the dataset: {duplicate_count}")
# Out:
# Number of duplicate rows in the dataset: 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count

null_count = hotel_df.isna().sum()
null_count
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %%
# Visualizing the missing values:

# Setting the plot size
plt.figure(figsize=(12,6))

# Code to plot the barplot
sns.barplot(x = null_count.index, y = null_count.values)

# Setting X-axis label:
plt.xlabel("Columns --->")

# Setting Y-axis label:
plt.ylabel("Number of Null Values --->")

# Setting the title of plot:
plt.title("Null Values among each column")


plt.xticks(rotation = 90) # Rotating the columns in X-axis to 90 degrees


plt.show()  # Showing the plot

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# *   Dataset contains 119390 rows and 32 columns.
#
# *   The various data type column include- float, integers and object.
#
# *   Out of 32 columns, there are 4 float data type columns, 16 integers type columns and 12 object data type columns.
#
# *   Number of duplicate rows in the dataset is 31994.
#
# *   The column 'company' has the highest number of null values, i.e 112593 followed by the column 'agent' having 16340 null values and then column 'country' and 'children' having null value count of 488 and 4 respectively.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns

hotel_df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe

hotel_df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - **Hotel**- H1= Resort Hotel, H2= City Hotel
#
# - **is_cancelled**- If the booking was cancelled(1) or not(0)
#
# - **lead_time**- Number of days that elapsed between the entering date of the booking into the PMS and the arrival date
#
#
# - **arrival_date_year**- Year of arrival date
#
# - **arrival_date_month**-  Month of arrival date
#
# - **arrival_date_week_number**- Week number for arrival date
#
# - **arrival_date_day_of_month**- Day of arrival date
#
# - **stays_in_weekend_nights**- Number of weekend nights (Saturday or Sunday) the guest stayed or booked to stay at the hotel
#
# - **stays_in_week_nights**- Number of week nights (Monday to Friday) the guest stayed or booked to stay at the hotel
#
# - **adults**- Number of adults
#
# - **children**- Number of children
#
# - **babies**- Number of babies
#
# - **meal**- Kind of meal opted for
#
# - **country**- Country code
#
# - **market_segment**- Which segment the customer belongs
#
# - **distribution_channel**- How the customer accessed the stay corporate booking/Direct/TA TO
#
# - **is_repeated_guest**- Guest coming for first time or not
#
# - **previous_cancellation**- Was there a cancellation before
#
# - **previous_bookings**- Count of previous bookings
#
# - **reserved_room_type**- Type of room reserved
#
# - **assigned_room_type**- Type of room assigned
#
# - **booking changes**- Count of changes made to booking
#
# - **deposit_type**- Deposit type
#
# - **agent**- Booked through agent
#
# - **days_in_waiting_list**- Number of days in waiting list
#
# - **customer_type**- Type of customer
#
# - **required_car_parking**- If car parking is required
#
# - **total_of_special_req**- Number of additional special requirements
#
# - **reservation_status**- Reservation of status
#
# - **reservation_status_date**- Date of the specific status

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.

for column in hotel_df.columns:
  unique_value_count = hotel_df[column].nunique()   # Calculating the number of unique values for each column
  unique_values = hotel_df[column].unique()         # Displaying all the unique values for each column
  print(f"Column: {column}\nUnique Value count: {unique_value_count}\nUnique values: {unique_values}\n")
# Out:
# Column: hotel
# Unique Value count: 2
# Unique values: ['Resort Hotel' 'City Hotel']
#
# Column: is_canceled
# Unique Value count: 2
# Unique values: [0 1]
#
# Column: lead_time
# Unique Value count: 479
# Unique values: [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

#Dropping rows with missing values:
hotel_df.dropna(subset = ['children'], axis = 0, inplace = True)

# %% [markdown]
# From variables description we can see that for columns like, 'is_canceled' and 'is_repeated_guest' the data 1 and 0 represents Yes and No respectively. So, i have renamed them as well as converted their data type from Integer to string/object.

# %%
#Code to make changes in data and data type:

def change_name(data):
  if data == 0:
    data = "No"
  elif data == 1:
    data = "Yes"
  return data


# Code to change the data name and data type of columns- "is_canceled" and "is_repeated_guest":

hotel_df["is_canceled"] = hotel_df["is_canceled"].apply(lambda x: change_name(x))

hotel_df["is_repeated_guest"] = hotel_df["is_repeated_guest"].apply(lambda x: change_name(x))


# Deleting duplicates:

hotel_df.drop_duplicates(inplace=True)

# %%
hotel_df.head()
# Out:
#           hotel is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel          No        342               2015               July
# 1  Resort Hotel          No        737               2015               July
# 2  Resort Hotel          No          7               2015               July
# 3  Resort Hotel          No         13               2015               July
# 4  Resort Hotel          No         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
hotel_df.shape
# Out:
# (87392, 32)

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# 1.   I dropped the rows with missing values for columns which i am going to use in data visualization.
#
# 2.   According to variables description, columns like, 'is_canceled' and 'is_repeated_guest' have values only in the form of 1 and 0 where the value 1 and 0 represents Yes and No respectively. So, i replaced 1 with Yes and 0 with No converting their data types from Integer to object simultaneously.
#
# 3.   I dropped the duplicate rows from the dataset updating its shape as 87392 rows and 32 columns.

# %% [markdown]
# ## ****4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables****

# %% [markdown]
# #### Distribution of Resort Hotel & City Hotel among Hotel

# %%
# Chart - 1 visualization code

# Storing the value count for each hotel type in hotel_value_count
hotel_value_count = hotel_df['hotel'].value_counts()

# Plotting the pie chart & setting legend and title
plt.pie(hotel_value_count, labels = hotel_value_count.index, autopct='%1.0f%%')
plt.legend(hotel_value_count.index, title='Hotel', loc = 'upper right')
plt.title("Distribution of City Hotel & Resort Hotel")

# Showing the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# City hotel and Resort hotel are different types of hotels inside the same column 'hotel'. So, to show the different parts of a whole i used pie chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There are 22% more City hotels as compared to Resort Hotels which is 39% of the whole.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, the gained insights can help in a positive business impact only by contributing to the operational efficiency and customer satisfaction of hotels.
# - By looking into the chart we can predict how much hold of customers different type of hotels can have and if acted upon, the hotels will be able to deliver satisfactory service to customers.

# %% [markdown]
# #### Distribution of type of meals among meal.

# %%
# Chart - 2 visualization code

# Storing meal value counts for each type of meal in meal_value_counts:
meal_value_counts = hotel_df['meal'].value_counts()

# Plotting the pie chart & setting legend and title:
plt.pie(meal_value_counts, labels = meal_value_counts.index, autopct ='%1.0f%%')
plt.legend(meal_value_counts.index, title = 'Meals', loc = 'lower left')
plt.title("Distribution of meals")

# Showing the chart:
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# BB, SC, HB, Fb and Undefined are different types of meals inside the same column 'meal'. So, to show the different parts of a whole i used pie chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - 78% of the customers opted for BB type of meal.
# - Percentage of customers opting for SC and HB meals are nearly the same, i.e 11% and 10% respectively.
# - While very rare customers(1%) opted for meal that is undefined and till now 0% customers opted for FB meal.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Yes, the gained insights can help in a positive business impact only by contributing to the operational efficiency of hotels.
#
# - By knowing the type of meal which is most opted, the hotel management would be able to give proper instuctions to hotel chefs about consumption rate of different types of meal options which will also lead to avoid food wastage contributing to the overall revenue of the business.

# %% [markdown]
# #### Distribution of market segement of customers coming to hotels

# %%
# Chart - 3 visualization code

# Storing different market segment and their counts in meal_value_counts:
market_segment_count = hotel_df['market_segment'].value_counts()

# Setting figure size, Plotting the bar chart:
plt.figure(figsize = (10,5))
sns.barplot(data = hotel_df, x= market_segment_count.index, y = market_segment_count.values)

# Setting labels for x and y axis and title of the plot:
plt.xlabel("Market Segments -->")
plt.ylabel("Counts -->")
plt.title("Customer Market Segments vs count")

# Displaying the plot:
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I wanted to compare categorical data with their frequency of a single categorical variable that's why i used bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Maximum customers, i.e approx 51000 are coming from Online TA(Travel Agents).
#
# - Decreasing counts of other segments are seen after Online TA followed by Offline TA/TO, Direct, Groups, Corporate, Complementary and Aviation.
#
# - Least number of customers are coming from Aviation sector.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The gained insight highlights significantly good number of people coming from Online TA market segments.
#
# - On the other hand, it also highlights the significant low count for other types for market segment for which customer satisfaction or operational ineffieciency or any other factor could be a possible reason.
#
# - For example, market segment like 'Groups' or 'corporate' could contribute to revenue of the business but their numbers are very low. So, using this insight hotel management could ask for feedback or rating from those segment of customers to know where the they are lacking.

# %% [markdown]
# #### Count of Customers type (Count Plot)

# %%
# Chart - 4 visualization code

# Plotting the Count Plot
sns.countplot(data = hotel_df, x = 'customer_type', hue = 'hotel')

# Setting labels, legend and plot title
plt.xlabel("Customer Type -->")
plt.ylabel("Count -->")
plt.legend(title = "Hotel Type")
plt.title("Customer Type vs count (Count Plot)")

# Showing the plot:
plt.plot()
# Out:
# []

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualise the frequency or count of occurrences of a particular category, i.e Customer type in a dataset i used count plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Customers falling into 'Transient' category have the maximum count for both type of hotels, i.e approx 26000 for Resort hotels & approx 44,000 for City Hotels.
#
# - Customers falling into 'Group' category have the least count for both type of hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The distribution of customer types is essential for hotels to tailor their strategies, services, and operations to meet the specific needs and expectations of each segment.
#
# - From the gained insights we can enhance the frequency count of Transient customers in Resort hotels also by comparing the serives and staff quality with City hotels as they already have good count of those customers type.
#
# - The insight is also highlighting very low frequency of customers from the cutomer type 'Group' and 'Contract' for both hotel types. This can be used by hotel management for improving their services in those customer types.

# %% [markdown]
# #### Reservation status for both Hotels

# %%
# Chart - 5 visualization code

# Reservation Status for Resort Hotels:
resort_hotel_df = hotel_df[hotel_df['hotel']=='Resort Hotel']   # Dataset containing only resort hotels in 'hotel' column
resort_hotel_df_reservation_status = resort_hotel_df['reservation_status'].value_counts() # Resort hotels reservation status value counts

# Reservation Status for City Hotels:
city_hotel_df = hotel_df[hotel_df['hotel'] == 'City Hotel']   # Dataset containing only City hotels in 'hotel' column
city_hotel_df_reservation_status = city_hotel_df['reservation_status'].value_counts()   # City hotels reservation status value counts

#Code for sub-plots:
plt.figure(figsize = (10,5))

# Plot 1- Reservation Status(Resort Hotel)
plt.subplot(121)
plt.pie(resort_hotel_df_reservation_status, labels = resort_hotel_df_reservation_status.index, autopct = '%1.0f%%')
plt.legend(resort_hotel_df_reservation_status.index, title = 'Reservation Status', loc = 'lower left')
plt.title("1. Reservation Status(Resort Hotel)")

# Setting title, legend and plotting the plot:
# Plot 2- Reservation Status(Resort Hotel)
plt.subplot(122)
plt.pie(city_hotel_df_reservation_status, labels = city_hotel_df_reservation_status.index, autopct = '%1.0f%%')
plt.legend(city_hotel_df_reservation_status.index, title = 'Reservation Status', loc = 'lower left')
plt.title("2. Reservation Status(City Hotel)")

plt.tight_layout()
plt.subplots_adjust(wspace=0.2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Check-out, Canceled and No-show are different types of reservation status under the same column 'reservation_status'. So, to show the different parts of a whole i used pie chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Majority of people have been checked out of their rooms, i.e 77% and 70% rooms are empty for Resort and city hotels respectively.
#
# - 1% of the customers are in No-show status for both type of hotels.
#
# - The cancellations in  Resort and City hotels are 23% and 29% respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The gained insights is enough to visualize the current occupancy status of both the hotels, therefore it could help in occupancy management, resourse allocation, overbooking management, etc.
#
# - If acted upon, these insights could help in increasing the occupational efficiency for both the hotels.

# %% [markdown]
# #### Distribution of distribution channel of customers.

# %%
# Chart - 6 visualization code

# Distribution channel count for Resort hotels:
resort_hotel_df = hotel_df[hotel_df['hotel']=='Resort Hotel']   # Dataset containing only resort hotels
resort_hotel_df_distribution_channel_count = resort_hotel_df['distribution_channel'].value_counts()

# Distribution channel count for City hotels:
city_hotel_df = hotel_df[hotel_df['hotel']=='City Hotel']   # Dataset containing only City hotels
city_hotel_df_distribution_channel_count = city_hotel_df['distribution_channel'].value_counts()

# Setting  size for sub-plots
plt.figure(figsize = (10,5))

# Plotting sub-plots
# subplot 1
plt.subplot(121)
plt.pie(resort_hotel_df_distribution_channel_count, labels = resort_hotel_df_distribution_channel_count.index, autopct = '%1.0f%%')
plt.legend(resort_hotel_df_distribution_channel_count.index, title = 'Distribution Channel', loc = 'lower left')
plt.title("1. Distribution Channel (Resort Hotel)")

# subplot 2
plt.subplot(122)
plt.pie(city_hotel_df_distribution_channel_count, labels = city_hotel_df_distribution_channel_count.index, autopct = '%1.0f%%')
plt.legend(city_hotel_df_distribution_channel_count.index, title = 'Distribution Channel', loc = 'lower left')
plt.title("2. Distribution Channel (City Hotel)")


plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# TA/TO, Direct, Corporate, GDS are different types of distribution channel for the same column 'distribution_channel'. So to visualize the distribution of different parts of a whole, i used pie chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Majority of cutomers, 72% and 83% customers in Resort hotel and city hotel  respectively are coming from the distribution channel TA/TO.
#
# - On the other hand, very few customers, i.e 7% and 5% customers in Resort hotel and city hotel  respectively are coming from the distribution channel corporate.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - As per the insights, majority of booking for both the hotels are coming from TA/TO, while the booking percentage from Direct category are very less. This could help the business to understand why its customers are not booking their rooms from hotel's website directly. Maybe slow website, pricing, marketing or any such factor could be a possible reason.
#
# - More bookings through hotel's website could help in building a brand loyality, maintaining control over booking process, pricing decisions, allocating inventory effectively and thus leading to overall profitability.

# %% [markdown]
# #### Total number of arrivals(adults+children+babies) vs month for each year.

# %%
# Chart - 7 visualization code

# Creating a data frame containing an aditional column for total number of arrivals:
hotel_df['total_arrival'] = hotel_df['adults'] + hotel_df['children'] + hotel_df['babies']
hotel_df['total_arrival'] = hotel_df['total_arrival'].astype(int)

# Grouping the hotel_df over arrival month and year for the sum of total arrivals:
grouped_hotel_df = hotel_df.groupby(['arrival_date_month', 'arrival_date_year'])['total_arrival'].sum()

# Code for Lineplot:
plt.figure(figsize = (10,5))
sns.lineplot(data = grouped_hotel_df, x = 'arrival_date_month', y = grouped_hotel_df.values, hue = 'arrival_date_year')
plt.legend(title = "Arrival Year")
plt.xlabel("Months -->")
plt.ylabel("Number of arrivals -->")
plt.title("Total no. of Arrivals (adults+children+babies) vs Month")

# Rotating the x-axis variables to 90 degrees and showing the plot:
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I had to visualize the trend of number of arrivals over different month for each year. So,  to visualize the trend of a data over time i used line plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - A similar pattern of upward trend(increase in number of arrival) in August and July and downward trend(decrrease in number of arrival) in January can be seen for years 2016 and 2017.
#
# - On the other hand, year 2015 has very few similarities with 2016 like both have an downward trend in November and an upward trend in October.
#
# - Overall, it can be also visualized that the number of arrivals has significantly increased after 2015.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The gained insight can be used by hotel management to predict the months having maximum numbers of arrival which could be helpful in providing better customer experience and resourse allocation.
#
# - At the same time the insights also highlight the areas of improvement like the month January, November for which the customer count is significantly dropping.

# %% [markdown]
# #### Number of (babies+children) vs month for each year.

# %%
# Chart - 8 visualization code

# Adding a column 'babies+children' to store the sum of column 'babies' and 'children' for each row:
hotel_df['babies+children'] = (hotel_df['babies'] + hotel_df['children']).astype(int)

# Grouping the sum of 'babies+children' column by columns 'arrival_date_month' and 'arrival_date_year':
child_babies_count = hotel_df.groupby(['arrival_date_month', 'arrival_date_year'])['babies+children'].sum()


# Code the scatter plot:
plt.figure(figsize = (10,5))
sns.scatterplot(data = child_babies_count, x = 'arrival_date_month', y = child_babies_count.values, hue = "arrival_date_year")

# Changing X and Y axis labeles, putting title and rotating the X-axis variables to 90 degrees:
plt.legend(title = "Arrival Year")    # To change the title of hue legend
plt.xlabel("Arrival Date Month -->")
plt.ylabel("Count -->")
plt.title("Count of (babies+children) vs Arrival month")
plt.xticks(rotation= 90)

# Showing the plot:
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualise the count of babies+children and arrival_date_month are two continuous variables. So, to explore the relationship between these two variables i used scatter plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - August and July are two peak months for maximum arrival of children and babies from last two years
#
# - While, months like December, January and November have the least arrival of babies and children.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Separately visualizing the number of children and babies are very important for the business as there are several measures to be taken care before children and babies count increase in hotel premises. These include troubleshooting security systems like CCTV around gates, swimming pools, increase of more hotel security staffs, maintainance of playgrounds and swings if any, etc.
#
# - Increase of children and babies count could also severely impact the consumption of milk and other types of babies food. So this insight will also help in adequate allocation of those resources.
#
# - Overall these will enhance the operational efficiency and customer experience of the hotel.

# %% [markdown]
# #### Number of cancelations vs arrival month for each year.

# %%
# Chart - 9 visualization code

# Creating a dataframe containing removing all 'No' from is_cancelled column:
canceled_hotel_df = hotel_df[hotel_df['is_canceled'] == 'Yes']

# Code to reflect '1' for each value of 'Yes' in 'is_canceled' column:
def change_value(data):
  if data == 'Yes':
    data = 1
  else:
    data = 0
  return data

# Adding another column 'is_canceled_count' to 'canceled_hotel_df'for storing the numeric value 1 for each 'Yes':
canceled_hotel_df['is_canceled_count'] = canceled_hotel_df['is_canceled'].apply(lambda x:change_value(x))

# Grouping the sum of 'is_canceled_count' column by 'arrival_data_month' and 'arrival_date_year':
grouped_canceled_hotel_df = canceled_hotel_df.groupby(['arrival_date_month', 'arrival_date_year'])['is_canceled_count'].sum().reset_index()

# Plotting the barplot:
plt.figure(figsize = (12,6))
sns.barplot(data = grouped_canceled_hotel_df, x = 'arrival_date_month', y = 'is_canceled_count', hue = 'arrival_date_year')

# Changing X and Y axis labeles, putting title and rotating the X-axis variables to 45 degrees:
plt.legend(title = "Year")    # To change the title of hue legend
plt.xlabel("Month -->")
plt.ylabel("Cancelation Count -->")
plt.title("Count of Cancelations vs Month")
plt.xticks(rotation= 45)

# Showing the plot
plt.show()
# Out:
# <ipython-input-147-7610605d18ae>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   canceled_hotel_df['is_canceled_count'] = canceled_hotel_df['is_canceled'].apply(lambda x:change_value(x))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Since 'arrival_date_month' is a categorial variable, therefore the compare the categorical data over the cancelation count i used a bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The maximum and minimum number of cancelations for year 2017 are in months of August and January respectively.
#
# - The maximum and minimum number of cancelations for year 2016 are also in months of August and January respectively.
#
# - The maximum number of cancelations for year 2015 are nearly same for August and September while the minimum number of cancelations are in November.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Keeping an eye on the number of cancelations is extremely important for the business as it could highlight both scenarios when the business is going up, i.e months having minimum cancelations as well as when the business is going down, i.e months having maximum cancelations.
#
# - From the gained insights we can see that month 'August' is common in 2015, 2016 and 2017 for the maximum number of cancelations. This information can be used by hotel management to check for problems and improvements for that specific month.
#
# - The cancelation trend could also be helpful in cancellation pattern recognition and checking if there other areas of improvement like customer satisfaction rate, quality of rooms provided, operational efficiency, pricing etc.

# %% [markdown]
# #### Total number of weekend night stays vs Month and comparison of weekend stays among each hotel type for each month.

# %%
# Chart - 10 visualization code

# Grouping the sum of 'stays_in_weekend_nights' by 'arrival_date_month':
grouped_weekend_stay = hotel_df.groupby(['arrival_date_month'])['stays_in_weekend_nights'].sum().reset_index()

# Grouping the sum of 'stays_in_weekend_nights' by 'arrival_date_month' and 'hotel':
grouped_weekend_stay_df_hue_hotel = hotel_df.groupby(['arrival_date_month', 'hotel'])['stays_in_weekend_nights'].sum().reset_index()

# Creating subplots:
plt.figure(figsize = (13,5))

# Subplot-1: Number of weekend night stays vs Month:
plt.subplot(121)
sns.barplot(data = grouped_weekend_stay, x = 'arrival_date_month', y = 'stays_in_weekend_nights')
plt.xlabel('Arrival Month -->')
plt.ylabel('Stays in weekend nights -->')
plt.title('1. Total number of weekend stays vs Arrival Month')
plt.xticks(rotation = 90)

# Subplot-2: Comparison of weekend night stays among each hotel for each Month:
plt.subplot(122)
sns.barplot(data = grouped_weekend_stay_df_hue_hotel, x = 'arrival_date_month', y = 'stays_in_weekend_nights', hue = 'hotel')
plt.xlabel('Arrival Month -->')
plt.ylabel('Stays in weekend nights -->')
plt.title('2. Number of weekend stays per hotel vs Arrival Month')
plt.legend(title = 'Hotel Type')
plt.xticks(rotation = 90)

# Adjusting the plot
plt.tight_layout()
plt.subplots_adjust(wspace=0.2)

# Showing the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# There are multiple categorical variables involved in the subplots, like 'arrival_date_month', 'hotel', 'stays_in_weekend_nights' and to visualize the comparison among them i used bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The maximum number of weekend night stays are in month of August, i.e 12911
# .
#
# - For August, Resort Hotels are going to have more weekend night(i.e 6876) stays than City hotels(i.e 6035).
#
# - The minimum number of weekend night stays are in month of January, i.e 3955.
#
# - For January, City Hotels are going to have more weekend night stays(i.e 2426) than Resort hotels(i.e 1529).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The gained insights could be very helpful in determining various things like resourse allocation, food consumption, deciding the number of staff among each hotel type according to the distribution of weekend night stays among hotel type, etc.
#
# - Overall, the insight could help the hotel management in adequate allocation of resources during weekends leading to enhanced customer experience.

# %% [markdown]
# #### Spread of 'lead_time' vs 'arrival_date_month' for each year.

# %%
# Chart - 11 visualization code

# Setting the plot size:
plt.figure(figsize = (12, 6))

# Plotting the plot:
sns.boxplot(data = hotel_df, x = 'arrival_date_month', y = 'lead_time', hue = 'arrival_date_year')

# Beaufying the plot:
plt.legend(title = 'Year')
plt.xlabel('Arrival Month -->')
plt.ylabel('Lead Time -->')
plt.title('Box Plot of Lead Time vs Month')
plt.xticks(rotation = 45)

# Showing the plot:
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the summary statistics (median, quartiles,
# and outliers) of a 'lead_time' which is a single continuous variable, i used box plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The outliers are predominantly on high side of the box plot, it indicates the data has right-skewness.
#
# - For year 2017, months July and August have maximum as well as similar lead time of somewhere around 400 and majority of data(lead time) lying approximately between 40 to 190.
#
# - For year 2016, month Spetember has maximum lead time of somewhere around 440 and majority of data(lead time) lying approximately between 20 to 160.
#
# - For year 2015, month Spetember has maximum lead time of somewhere around 250 and majority of data(lead time) lying approximately between 10 to 110.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The "lead time" is a valuable metric for hotel management and analysis because it provides insights into the booking patterns and trends of guests.
#
# - Lead time could also be helpful in understanding other factors like:
#   - Booking Horizon: How far in advance do guests typically make their reservations? This could help hotel management to plan for staffing, inventory, and pricing strategies.
#
#   - Forecasting: Lead time can be used in forecasting demand and occupancy levels, allowing hotels to allocate resources effectively.
#
#   - Seasonality: Does lead time vary based on the season or time of year? Understanding seasonality could help hotels adjust their marketing and pricing strategies accordingly.

# %% [markdown]
# #### Brief visualization of number of cancellations by hotel type and market segment.

# %%
# Chart - 12 visualization code

# Grouping the sum of 'previous_cancellations' by 'hotel' to know which hotel has more cancellations:
groupby_hotel_prev_canellations = hotel_df.groupby('hotel')['previous_cancellations'].sum().reset_index()

# Grouping the sum of 'previous_cancellations' by 'market_segment' and 'hotel' to visualize number of cancellations for each h market segment each hotel type:
groupby_market_seg_prev_cancellations = hotel_df.groupby(['market_segment', 'hotel'])['previous_cancellations'].sum().reset_index()

# Creating subplots:
plt.figure(figsize = (13,5))  # Setting the plot figure size

# Subplot 1
plt.subplot(121)
sns.barplot(data = groupby_hotel_prev_canellations, x = 'hotel', y = 'previous_cancellations')
plt.xlabel("Hotel Type -->")
plt.ylabel("Number of cancellations -->")
plt.title("Plot 1. Number of cancellations vs Hotel type")


# Subplot 2
plt.subplot(122)
sns.barplot(data = groupby_market_seg_prev_cancellations, x = 'market_segment', y = 'previous_cancellations', hue = 'hotel')
plt.xlabel("Market Segments -->")
plt.ylabel("Number of cancellations -->")
plt.title("Plot 2. Number of cancellation vs Market Segments")
plt.legend(title = "Hotel Type", loc = 'upper left')
plt.xticks(rotation = 90)

plt.tight_layout()
plt.subplots_adjust(wspace = 0.2)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The variables required to visualize the above scenario involves categorical data and hence i used bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Plot 1:
#   - City hotels have approximately more than twice of cancellations in resort hotels.
#
# Plot 2:
#   - For city hotels market segment from 'online TA' and 'Aviation' have maximum and minimum cancellations respectively.
#
#   - For Resort hotels market segment from 'Corporate' and 'Aviation' have maximum and minimum cancellations respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The plot highlights that cancellation count for city hotel is more than resort hotels. This insight could be useful to check for the possible reasons for such a high number of cancellations.
#
# - From plot 2, it can be easily visualized that customers in city hotel specially from online TA and corporate market segments have a high number of cancellation counts. This insight could be used to take feedback from the Online Travel Agent and corporate and their customers to identify the root cause.
#
# - Overall these insights could help the hotel management to indentify the cancellation trend as well as its root cause which could further improve the customer satisfaction level.

# %% [markdown]
# #### Count of changes made to booking vs market segment.

# %%
# Chart - 13 visualization code

# Grouping the sum of booking_changes by market_segment :
groupby_market_seg_booking_changes = hotel_df.groupby('market_segment')['booking_changes'].sum().reset_index()

# Plotting the chart:
plt.figure(figsize = (8,4))
sns.barplot(data = groupby_market_seg_booking_changes, x = 'market_segment', y = 'booking_changes')

# Beautifying the chart:
plt.xticks(rotation = 90)
plt.xlabel("Market Segments -->")
plt.ylabel("Count of booking changes -->")
plt.title("Count of booking changes vs Market Segment")

# Showing the plot:
plt.plot()
# Out:
# []

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the count of numeric variable for a categorical variable i used bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The maximum and minimum number of booking changes are from customers coming from 'Online TA' and 'Aviation' market segment respectively.
#
# - After Online TA, 'Direct' market segment are having the maximum numbers of booking changes followed by 'Offline TA/TO' and 'Groups'.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The number of booking changes could be indicative of the quality of service provided by the hotel. A high number of changes might suggest that customers are dissatisfied with their initial bookings or that there are issues with the hotel's reservation system. This information can help the hotel identify areas for improvement. Example- Online TA which has most booking changes.
#
# - Monitoring booking changes can help hotels understand customer preferences and needs. By analyzing the reasons behind changes (e.g., room type, date modifications, special requests), hotels can tailor their services to better meet customer expectations and enhance overall satisfaction.
#
# - Reducing the need for booking changes can improve the hotel's operational efficiency. By addressing common issues that lead to changes (e.g., room cleanliness, maintenance, amenities), hotels can minimize disruptions and provide a smoother experience for guests.
#
# - In summary, tracking the count of booking changes made by customers provide valuable insights for hotels to enhance customer satisfaction, optimize revenue, improve operational effieciency.

# %% [markdown]
# #### Number of repeated guests vs market segment for hotel type.

# %%
# Chart - 14 visualization code

# Data frame containing only repreated customers entry for 'is_repeated_guest(guest coming for first time or not)' column:
repeated_guest_df = hotel_df[hotel_df['is_repeated_guest'] == 'No']

# Custom function to convert each No to 1 in order to count total No for each market segment:
def value_converter(data):
  if data == 'No':
    data = 1
  else:
    data = 0
  return data

# Adding separate column 'is_repeated_count' to store the numeric value for each No:
repeated_guest_df['is_repeated_count'] = repeated_guest_df['is_repeated_guest'].apply(lambda x: value_converter(x))

# Grouping the sum of 'is_repeated_count' by 'market_segment' and 'hotel':
groupby_market_seg_repeated_guest_df = repeated_guest_df.groupby(['market_segment', 'hotel'])['is_repeated_count'].sum().reset_index()

# Plotting the plot:
plt.figure(figsize = (8, 4.5))
sns.barplot(data = groupby_market_seg_repeated_guest_df, x = 'market_segment', y = 'is_repeated_count', hue = 'hotel')

# Beautifying the plot:
plt.xlabel("Market Segments -->")
plt.ylabel("Repeated Customers Count -->")
plt.title("Repeated Customers Count vs Market Segments")
plt.legend(title = "Hotel Type", loc = "upper left")
plt.xticks(rotation = 45)

# Showing the plot
plt.show()
# Out:
# <ipython-input-152-235b8c313597>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   repeated_guest_df['is_repeated_count'] = repeated_guest_df['is_repeated_guest'].apply(lambda x: value_converter(x))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the comparison of various categorical varibales like 'Market Segment' and 'Repated customers' i used bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - City hotel has an overall more number of repeated customers count over Resort hotel.
#
# - Fore City hotel, 'Online TA' and 'Aviation' has most and least number of repeated customers respectively.
#
# - Fore Resort hotels, 'Online TA' and 'complementary' has most and least number of repeated customers respectively.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Number of Repeated customers could be indicative of quality of service and customer experience provided by the hotel. A high number of repeated customers indicate that customers are satisfied by the quality of service they're getting during their stay. This insight can be used by hotel to identify the areas of improvement.
#
# - For example in city hotels and resort hotels, customers from 'Aviation' and 'complementary' market segment have least number of repetition count respectively. So using this insight, hotels could tailor their services, specifically for these market segment and indentify the root cause.
#
# - Improving the repetition count of customers could enhance customer satisfaction as well as optimize revenue.

# %% [markdown]
# #### Total number of special requests vs customer type for each hotel type.

# %%
# Chart - 15 visualization code

# Grouping the sum of 'is_repeated_count' by 'total_of_special_requests' by 'customer_type' and 'hotel':
groupby_customer_type_spl_req = hotel_df.groupby(['customer_type', 'hotel'])['total_of_special_requests'].sum().reset_index()

# Plotting the chart:
sns.barplot(data = groupby_customer_type_spl_req, x = 'customer_type', y = 'total_of_special_requests', hue = 'hotel')

# Beautifying the chart:
plt.xlabel("Customer Type -->")
plt.ylabel("Number of Special requests -->")
plt.title("Number of Special requests vs Customer Type")
plt.legend(title ="Hotel type", loc = 'upper right')

# Showing the plot:
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the comparison of a categorical variable, i used bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The maximum number of special requests are from 'Transient' customer type for both City and Resort hotels.
#
# - While the minimum number of special requests are from 'Group' customer type for both City and Resort hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Special request could be indicative of specific requirements by a particular customer type for their stay. Therefore, tracking the total number of special requests could be benifitial for the hotel in the following ways:
#   - **Customer Satisfaction:** Tracking special requests allows hotels to better cater to the needs and preferences of different customer segments. By fulfilling special requests promptly and accurately, hotels can enhance customer satisfaction and create a positive guest experience.
#
#   - **Service Planning:** Knowing the total number of special requests for each customer type helps hotels allocate resources efficiently. For example, if transient guests frequently request extra pillows or towels, the hotel can ensure an adequate supply of these items in transient rooms.
#
#   - **Guest Loyalty:** Meeting and exceeding special requests can lead to guest loyalty and positive reviews. Satisfied customers are more likely to return to the same hotel for future stays and recommend it to others.
#
#   - **Competitive Advantage:** Providing exceptional service and fulfilling special requests can give a hotel a competitive edge in the market. It can set the hotel apart from competitors and attract more guests.
#
# - In summary, tracking the total number of special requests for different customer types is essential for delivering excellent customer service, optimizing operations, and tailoring services to guest preferences. It can lead to increased guest satisfaction, loyalty, and revenue generation for hotels.

# %% [markdown]
# #### Total number special requests vs Assigned room type for each hotel.

# %%
# Chart - 16 visualization code

# Grouping the sum of 'total_of_special_requests' by 'assigned_room_type' & 'hotel':
groupby_assinged_room_spl_req = hotel_df.groupby(['assigned_room_type', 'hotel'])['total_of_special_requests'].sum().reset_index()

# Plotting the graph:
sns.lineplot(data = groupby_assinged_room_spl_req, x = 'assigned_room_type', y = 'total_of_special_requests', hue = 'hotel')

# Beautifying the graph:
plt.xlabel("Assigned Room Type -->")
plt.ylabel("Number of special requests -- >")
plt.title("Count of Special requests vs Assigned room type")
plt.legend(title = "Hotel Type")

# Showing the graph:
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the trend of number of special requests over different room types, i used line chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Assigned room 'A' has the maximum number of special requests for both city and resort hotels.
#
# - Assigned room 'L' and 'P' have the least number of special requests for both city and resort hotels.
#
# - Number of special requests in City hotel is significantly high as compared to Resort hotel in case of assigned room 'A'.
#
# - City Hotel has an overall more number of special requests over Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - The number of special requests for a particular room type could be indicative of guest preferences, amenity demand, operational efficiency, room preferences, areas of improvement etc.
#
# - For example assiged room 'A' has most number of special requests. There can be many possible reasons like- may be guests usually used to demand amenities like extra pillow or towel or corporate sector guests may deamand dedicated working space.
#
# - In summary, the insight can help hotels understand which room types lead to more positive guest experiences and reviews, as well as which types may need improvement.

# %% [markdown]
# #### Total stays in week nights vs arrival month for each hotel type.

# %%
# Chart - 17 visualization code

# Grouping the sum of 'stays_in_week_nights' by 'arrival_date_month':
grouped_week_stay = hotel_df.groupby(['arrival_date_month'])['stays_in_week_nights'].sum().reset_index()

# Grouping the sum of 'stays_in_week_nights' by 'arrival_date_month' and 'hotel':
grouped_week_stay_df_hue_hotel = hotel_df.groupby(['arrival_date_month', 'hotel'])['stays_in_week_nights'].sum().reset_index()

# Creating subplots:
plt.figure(figsize = (13,5))

# Subplot-1: Number of week night stays vs Month:
plt.subplot(121)
sns.barplot(data = grouped_week_stay, x = 'arrival_date_month', y = 'stays_in_week_nights')
plt.xlabel('Arrival Month -->')
plt.ylabel('Stays in week nights -->')
plt.title('1. Total number of week stays vs Arrival Month')
plt.xticks(rotation = 90)

# Subplot-2: Comparison of week night stays among each hotel for each Month:
plt.subplot(122)
sns.barplot(data = grouped_week_stay_df_hue_hotel, x = 'arrival_date_month', y = 'stays_in_week_nights', hue = 'hotel')
plt.xlabel('Arrival Month -->')
plt.ylabel('Stays in week nights -->')
plt.title('2. Number of week stays per hotel vs Arrival Month')
plt.legend(title = 'Hotel Type')
plt.xticks(rotation = 90)

# Adjusting the plot
plt.tight_layout()
plt.subplots_adjust(wspace=0.2)

# Showing the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# There are multiple categorical variables involved in the subplots, like 'arrival_date_month', 'hotel', 'stays_in_week_nights' and to visualize the comparison among them i used bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The maximum number of week night stays are in month of August, i.e 34987
# .
# - For August, Resort Hotels are going to have more week night(i.e 17716) stays than City hotels(i.e 16271).
#
# - The minimum number of week night stays are in month of January, i.e 10957.
#
# - For January, City Hotels are going to have more week night stays(i.e 6642) than Resort hotels(i.e 4315).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - As number of week stays plays a major role in the overall revenue of hotel, therefore keeping track of it is very essential in order to determine various things like resourse allocation, food consumption, deciding the number of staff among each hotel type according to the distribution of week stays among hotel type, etc.
#
# - The insight could also highlights an area of improvement in December, January and November months where the number of week stays are significantly low. Using this insight hotel can check if there is any factor responsible for it or it's just a season pattern.
#
# - Overall, the insight could help the hotel by highlighting possible areas of improvement as well as creating a positive business impact (like increasing revenue, enhancing operational efficiency,improved guest's experience, etc).

# %% [markdown]
# #### Count of previous bookings for each market segment.

# %%
# Chart - 18 visualization code

# Grouping the sum of previous bookings for each market segment:
grouped_prev_booking = hotel_df.groupby('market_segment')['previous_bookings_not_canceled'].sum().reset_index()

# Plotting the graph:
plt.figure(figsize = (8,4))
sns.barplot(data = grouped_prev_booking, x="market_segment", y = "previous_bookings_not_canceled")

# Beautifying the graph:
plt.xlabel('Market Segment -->')
plt.ylabel('Previous Bookings-->')
plt.title('Count of previous bookings vs Market segment')
plt.xticks(rotation = 45)

# Showing the plot:
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the previous bookings over a categorical variable 'market_segment' i used bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The market segment 'Corporate' has the maximum number of previous stays.
#
# - While 'Aviation' market segment has the least number of previous stays.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# - Count of previous stays for a particular market segment could be indicative of the loyality, operational efficiency, areas of improvement of a hotel.
#
# - For an example the count of previous stays for 'corporate' market segment is quite good which indicates that guests belonging to this sector are loyal to the hotel due to various reasons like room ambience, staff service or behaviour, food quality, etc.
#
# - On the other hand, count of previous stays for 'Groups' and 'Aviation' customer segments are very low which indicates that there may be some kind of improvement needed in certain areas which may include room abience, asssigned room type, food or etc according to the preferences of these market segment guests.
#
# - In summary, using the insights hotel can increase the count of previous bookings for each market segment which could further result in improved guest staisfaction, high revenue, etc.

# %% [markdown]
# #### Spread of Lead time with respect to each market segment.

# %%
# Chart - 19 visualization code


# Plotting the graph:
plt.figure(figsize = (12,6))
sns.boxplot(data = hotel_df, x="lead_time", y = "market_segment")

# Beautifying the graph:
plt.xlabel("Count of Lead Time -->")
plt.ylabel("Market Segments -->")
plt.title("Market Segment vs Spread of Lead Time")
#plt.legend(title = 'Arrival Year')
plt.xticks(rotation = 90)

# Showing the graph:
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the spread of lead time, i.e, minimum, median, maximum, first, second and third quartile for each market segment of customer i used box plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - The outliers are predominantly on high side of the box plot, it indicates the data has right-skewness.
#
# - The market segment 'Groups' has the maximum lead time(approx 520) and mean lead time of approx 120.
#
# - The market segment 'Aviation' has the least lead time(approx 20) and mean lead time of approx 5.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Analyzing the spread of lead time across different market segments in a hotel booking dataset can provide several insights and valuable information, including:
#
# -  **Booking Behavior by Market Segment:** It can reveal how different market segments behave when it comes to lead time. For example, leisure travelers may book well in advance, while business like 'corporate' travelers may have shorter lead times due to the nature of their trips.
#
# - **Lead Time Affecting Availability:** Longer lead times can affect room availability, especially during peak seasons or for in-demand room types. Understanding this relationship helps hotels manage inventory and allocate resources effectively.
#
# - **Pricing and Revenue Management:** The relationship between lead time and market segment can inform pricing and revenue management strategies. Hotels can adjust pricing based on lead time trends for each segment to maximize revenue.
#
# - **No-Show and Cancellation Rates:** Guests with shorter lead times may have higher no-show or cancellation rates. Hotels can use this information to implement policies that mitigate revenue loss due to cancellations.
#
# In summary, the spread of lead time across different market segments provides insights into guest behavior, booking patterns, and opportunities for optimizing pricing, marketing, and operations to better serve each segment.

# %% [markdown]
# #### Relation between number of repeated customers and number of booking changes over year 2015, 2016 and 2017 for different market segment of customers.

# %%
# Chart - 20 visualization code

# Creating a copy of hotel_df to manipulate it further:
repeated_guest_df = hotel_df

# Custom function to convert each 'No' to 1 in order to count total 'No' for each market segment:
def change_value(data):
  if data == 'No':
    data = 1
  elif data == 'Yes':
    data = 0
  return data

# Adding separate column 'is_repeated_count' to store the numeric value for each No:
repeated_guest_df['is_repeated_count'] = repeated_guest_df['is_repeated_guest'].apply(lambda x: change_value(x))

# Grouping the sum of 'is_repeated_count' and 'booking_changes' by 'market_segment' and 'arrival_date_year':
grouped_repeated_guest_df = repeated_guest_df.groupby(['market_segment','arrival_date_year'])['is_repeated_count','booking_changes'].sum().reset_index()

# Plotting the plot:
sns.scatterplot(data = grouped_repeated_guest_df, x = 'booking_changes', y = 'is_repeated_count', hue = 'arrival_date_year')

# Beautifying the plot:
plt.xlabel("Booking changes -->")
plt.ylabel("Repeated guests count -->")
plt.title("Repeated Guests count vs. Booking changes")
plt.legend(title = 'Arrival Year', loc = 'lower right')

# Showing the plot:
plt.show()
# Out:
# <ipython-input-158-e51e6bd3e484>:18: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   grouped_repeated_guest_df = repeated_guest_df.groupby(['market_segment','arrival_date_year'])['is_repeated_count','booking_changes'].sum().reset_index()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the correlation between two variables i used scatter chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - An increase in the number repeated guests count is seen as the number of booking changes increase showing a positive correlation between them.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Analyzing the correlation between repeated guests count and booking changes can provide several insights resulting in positive business impact like:
#
# - **Guest Loyalty:** A positive correlation suggests that customers who make more booking changes tend to be repeat guests. This indicates that loyal or returning guests are more likely to make adjustments to their reservations. Insights into guest loyalty can inform customer retention strategies and loyalty programs.
#
# - **Accommodation Preferences:** Guests who make multiple booking changes may have specific accommodation preferences. They might be particular about room types, views, or other room features. Understanding these preferences can help hotels allocate rooms that match guest expectations.
#
# - **Revenue Opportunities:** Recognizing the relationship between guest loyalty and booking changes can lead to revenue opportunities. Hotels can offer add-on services or upsell room upgrades to capitalize on the preferences of repeat guests.
#
# - **Marketing and Targeting:** Hotels can use this correlation to target and market to repeat guests more effectively. Tailored marketing campaigns can be designed to attract and retain this specific segment of customers.
#
# In summary, these informations can be leveraged to improve guest satisfaction, retention, and revenue generation.

# %% [markdown]
# #### Chart - 21 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

sns.set(font_scale=0.8)   # To manipulate the font scale
plt.figure(figsize = (14,10))
sns.heatmap(data = hotel_df.corr(), annot = True, cmap = 'coolwarm', fmt=".2f", linewidths=0.5)

# Showing the plot:
plt.show()
# Out:
# <ipython-input-159-c741747df3b1>:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data = hotel_df.corr(), annot = True, cmap = 'coolwarm', fmt=".2f", linewidths=0.5)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize the correlation between each numeric variable of the dataset at once, i used heatmap.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# - Two columns with positive number in their adjacent common columns are having positive correlation.
#
# - Those two columns with a negative number in their common adjacent columns are having negative correlation.
#
# - Those two columns with 1 in their common adjacent columns are having linear correlation.

# %% [markdown]
# #### Chart - 22 - Pair Plot

# %%
# Pair Plot visualization code

# As pairplot only uses numerical columns to generate the plot, so removing all the non-numerical columns:
numerical_columns = hotel_df.select_dtypes(include=['number'])

# Removing extra added columns, un-used and non-relevant columns:
numerical_columns.drop(columns = ['total_arrival', 'babies+children', 'is_repeated_count', 'agent', 'company', 'adr', 'required_car_parking_spaces'], inplace = True)
numerical_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87392 entries, 0 to 119389
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   lead_time                       87392 non-null  int64
#  1   arrival_date_year               87392 non-null  int64
#  2   arrival_date_week_number        87392 non-null  int64
#  3   arrival_date_day_of_month       87392 non-null  int64
#  4   stays_in_weekend_nights         87392 non-null  int64
#  5   stays_in_week_nights            87392 non-null  int64
#  6   adults                          87392 non-null  int64
#  7   children                        87392 non-null  float64
#  8   babies                          87392 non-null  int64
#  9   previous_cancellations          87392 non-null  int64
#  10  previous_bookings_not_canceled  87392 non-null  int64
#  11  booking_changes                 87392 non-null  int64
# ...

# %%
# Plotting the pair plot:
plt.figure(figsize = (3,3))
sns.pairplot(data = numerical_columns)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize relationships between multiple pairs of continuous variables and identify the correlation and patterns among them simultaneously, i used pair plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There are many insights found from the above pair plot. Some of which are:
#
# 1. stays_in_week_nights and stays_in_weekend_nights have a positive correlation.
#
# 2. lead_time and also increases as days_in_waiting list increases.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on each insights gained from the above plots. The following solutions is advisable to the client:
#
# 1. The consumption of BB meal type is 78% among all meal types. So it's quantity should be sufficient.
#
# 2. Maket segments like groups and corporate could contribute significantly to the revenue of hotels but their count is quite low. So, services should be tailored targetting these market groups to increase their arrival count.
#
# 3. Customer type transient-party and contract also have low count. So, services should be tailored targetting these customer types also to increase their arrival count.
#
# 4. The cancellation percentages for both the hotels are high, i.e 23% for Resort Hotel and 29% for city hotel, these should be lowered for increased revenue.
#
# 5. The majority of customers coming to hotels are from TA/TO distribution channel while the percentage of customers doing their booking from direct hotels are quite low. So, hotel's online booking website should be focused to check for problems.
#
# 6. Months August and June have the maximum number arrivals. So, proper serives like enough hotel staff, food quantity, and maintainance should be done to improve customer satisfaction rate.
#
# 7. August and July are two peak months for maximum arrival of children and babies from last two years. So, extra security arrangements, foods consumed by babies like milk and other necessary arrangement should be there in hotel premises to avoid any accidents or mishaps.
#
# 8. Month 'August' is common in 2015, 2016 and 2017 for the maximum number of cancelations. It should be checked whether there are areas of improvement like customer satisfaction rate, quality of rooms provided, operational efficiency, pricing etc.
#
# 9. The maximum number of weekend night stays are in month of August, i.e 12911. Adequate allocation of resources should be ensured during weekends to enhance customer experience.
#
# 10.  Theere are different maket segments having the maximum number of cancellations for both hotels. The cancellation trend should be observed and a feedback system should be started to identify its root cause which could further improve the customer satisfaction level.
#
# 11. Online TA market segment have the maximum number of booking changes. The reasons behind changes (e.g., room type, date modifications, special requests), should be analyzed by hotels to tailor their services to better meet customer expectations and enhance overall satisfaction.
#
# 12. In city hotels and resort hotels, customers from 'Aviation' and 'complementary' market segment have least number of repetition count respectively. Hotels should tailor their services, specifically for these market segment and indentify the root cause.
#
# 13. The number of special requests are maximum for Transient customer types. Special request could be indicative of specific requirements by a particular customer type for their stay. So, tracking the number of special requests is important for service planning and gaining competitive advantage.
#
# 14. Assigned room 'A' has the maximum number of special requests for both city and resort hotels. Severl amenities should be checked for this room type for positive guest experiences and reviews.
#
# 15. In December, January and November months, the number of week stays are significantly low. As week stay also plays a major role in revenue, therefore hotels should check if there is any factor responsible for it or it's just a season pattern.
#
# 16. Count of previous stays for 'Groups' and 'Aviation' customer segments are very low which indicates that there may be some kind of improvement needed in certain areas which may include room abience, asssigned room type, food or etc according to the preferences of these market segment guests.
#
# 17. An increase in the number repeated guests count is seen as the number of booking changes increase showing a positive correlation between them. The correlation between repeated guests count and booking changes can provide several insights resulting in positive business impact like Guest Loyalty, Accommodation Preferences, Revenue Opportunities.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In conclusion, my exploratory data analysis of the hotel booking dataset has provided valuable insights into the dynamics of the hotel industry, guest behavior, and seasonal trends. I have identified key patterns that can guide hotel management in making informed decisions and enhancing the overall guest experience.
#
# **Seasonal Trends:** My analysis revealed a pronounced seasonal pattern in hotel bookings, with a peak in demand during the summer months. Understanding these fluctuations is essential for optimizing staffing levels, pricing strategies, and marketing efforts throughout the year.
#
# **Cancellation Rates:** I observed varying cancellation rates between city and resort hotels, with city hotels experiencing higher cancellations. This finding emphasizes the importance of implementing effective overbooking management strategies and flexible booking policies, especially for urban establishments.
#
# **Customer Segmentation:** By delving into market segments, i identified "Transient" and "Transient-Party" segments as the most frequent guests. Tailoring services and marketing campaigns to the preferences of these customer types can result in increased bookings and guest satisfaction.
#
# **Lead Time Impact:** Longer lead times were associated with a higher likelihood of booking confirmation. This knowledge can help hotel managers forecast demand and allocate resources more efficiently, particularly during high-demand periods.
#
# **Special Requests:** The analysis of special requests and their association with customer types highlights an opportunity for hotels to enhance guest satisfaction. Meeting special requests more consistently can significantly improve the overall guest experience.
#
# **Booking Channels:** Our examination of booking channels revealed the popularity of Online Travel Agencies (OTAs) among guests. To attract a broader audience, hotels should consider optimizing their online presence on these platforms.
#
# **Customer Retention:** The study of repeated guests and their booking behavior opens the door to customer retention strategies. By introducing incentives or loyalty programs, hotels can foster long-term relationships and increase guest loyalty.
#
# In light of these findings, I recommend city hotels to implement more flexible booking policies, optimize pricing strategies during peak seasons, and focus on customer retention. For resort hotels, enhancing the guest experience for families and leisure travelers should be a priority.
#
# It's important to acknowledge that this analysis is based on historical data, and external factors may influence booking trends. Continuous monitoring and adaptability will be essential for staying competitive in the dynamic hotel industry.
#
# My EDA project provides a foundation for future research into the impact of online reviews, geographic location, and other factors on booking decisions. By remaining attuned to industry trends and evolving guest preferences, hotels can secure their positions as premier destinations for travelers.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
